# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# load the data
data = pd.read_csv("malaria_control_africa.csv")
data.head()
# Out:
#   iso3 country  year  malaria_incidence_per_1000_at_risk  \
# 0  AGO  Angola  2000                          326.539432
# 1  AGO  Angola  2001                          330.804593
# 2  AGO  Angola  2002                          315.697197
# 3  AGO  Angola  2003                          319.287503
# 4  AGO  Angola  2004                          312.646868
#
#    health_expenditure_per_capita_usd  rural_population_pct  \
# 0                          13.159986             49.492935
# 1                          29.260958             48.277521
# 2                          29.370771             47.107377
# 3                          35.220695             45.995645
# 4                          50.233109             44.955472
#
#    gdp_per_capita_usd  population_total  forest_area_pct  population_density  \
# 0          563.733796        16194869.0        62.331443           12.990189
# 1          533.586202        16747208.0        61.886219           13.433230
# ...
