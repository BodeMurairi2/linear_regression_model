# %%
import warnings
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
# Source 1: WHO Global health Observatory -malaria incidence (target)
who_df = pd.read_csv("who_malaria_incidence_raw.csv")
who_df.head()
# Out:
#   iso3  year  malaria_incidence_per_1000_at_risk
# 0  ERI  2012                           17.281267
# 1  GAB  2009                          147.033263
# 2  CPV  2011                            0.052641
# 3  RWA  2009                          153.736952
# 4  GHA  2003                          365.979338

# %%
# Source 2 World Bank Open Data indicators (features)
worldbank_df = pd.read_csv("worldbank_indicators_raw.csv")
worldbank_df.head()
# Out:
#   iso3  year  health_expenditure_per_capita_usd  rural_population_pct  \
# 0  AGO  2000                          13.159986             49.492935
# 1  AGO  2001                          29.260958             48.277521
# 2  AGO  2002                          29.370771             47.107377
# 3  AGO  2003                          35.220695             45.995645
# 4  AGO  2004                          50.233109             44.955472
#
#    gdp_per_capita_usd  population_total  forest_area_pct  population_density  \
# 0          563.733796          16194869        62.331443           12.990189
# 1          533.586202          16747208        61.886219           13.433230
# 2          999.065856          17327699        61.440995           13.898852
# 3         1133.663320          17943712        60.995770           14.392967
# 4         1451.471179          18600423        60.550546           14.919726
#
#    under5_mortality_per_1000  life_expectancy_years  basic_water_access_pct  \
# 0                      185.0                 46.501               37.842237
# 1                      176.3                 47.032               38.338816
# 2                      166.4                 47.874               38.835392
# 3                      155.5                 50.218               40.396516
# 4                      143.7                 51.123               41.977237
#
#    urban_population_pct  govt_health_exp_pct_gdp  primary_completion_rate_pct  \
# 0             50.507065                 0.980978                          NaN
# 1             51.722479                 1.806842                          NaN
# 2             52.892623                 1.155481                          NaN
# 3             54.004355                 1.283358                          NaN
# 4             55.044528                 1.471358                          NaN
#
#    fertility_rate_births_per_woman country
# 0                            6.639  Angola
# 1                            6.601  Angola
# 2                            6.567  Angola
# 3                            6.533  Angola
# 4                            6.499  Angola

# %%
data = who_df.merge(worldbank_df, on=["iso3", "year"], how="inner")
data.to_csv("malaria_control_africa.csv", index=False)

# %%
# load the data
data = pd.read_csv("malaria_control_africa.csv")
data.head()
#data["fertility_rate_births_per_woman"].min()
# Out:
#   iso3  year  malaria_incidence_per_1000_at_risk  \
# 0  ERI  2012                           17.281267
# 1  GAB  2009                          147.033263
# 2  CPV  2011                            0.052641
# 3  RWA  2009                          153.736952
# 4  GHA  2003                          365.979338
#
#    health_expenditure_per_capita_usd  rural_population_pct  \
# 0                          27.786890             64.317574
# 1                         277.629456             14.256742
# 2                         157.089996             37.258007
# 3                          43.996414             83.079311
# 4                          18.964237             53.945203
#
#    gdp_per_capita_usd  population_total  forest_area_pct  population_density  \
# 0                 NaN           3036988         8.924026           25.082052
# 1         7290.575261           1661556        91.801409            6.448387
# 2         4002.013869            511447        10.674938          126.909926
# 3          556.973996          10060432        10.830969          407.800243
# 4          358.399271          21296705        37.694058           93.595434
#
#    under5_mortality_per_1000  life_expectancy_years  basic_water_access_pct  \
# 0                       51.4                 64.697               50.329175
# 1                       55.6                 64.361               84.130721
# 2                       25.6                 72.913               83.522244
# 3                       69.1                 61.813               52.968794
# 4                       88.2                 59.014               68.303644
#
#    urban_population_pct  govt_health_exp_pct_gdp  primary_completion_rate_pct  \
# 0             35.682426                 0.790661                    58.199478
# 1             85.743258                 1.540668                          NaN
# 2             62.741993                 2.611801                    91.221239
# 3             16.920689                 1.881071                    72.608017
# 4             46.054797                 0.943455                    65.334846
#
#    fertility_rate_births_per_woman     country
# 0                            4.407     Eritrea
# 1                            4.138       Gabon
# 2                            2.329  Cabo Verde
# 3                            4.707      Rwanda
# 4                            4.597       Ghana

# %%
# shape of data
nbrs_rows, nbr_columns = data.shape
print("Number of rows:", nbrs_rows)
print("Number of columns:", nbr_columns)
# Out:
# Number of rows: 1226
# Number of columns: 17

# %%
# columns name
data.columns
# Out:
# Index(['iso3', 'year', 'malaria_incidence_per_1000_at_risk',
#        'health_expenditure_per_capita_usd', 'rural_population_pct',
#        'gdp_per_capita_usd', 'population_total', 'forest_area_pct',
#        'population_density', 'under5_mortality_per_1000',
#        'life_expectancy_years', 'basic_water_access_pct',
#        'urban_population_pct', 'govt_health_exp_pct_gdp',
#        'primary_completion_rate_pct', 'fertility_rate_births_per_woman',
#        'country'],
#       dtype='object')

# %%
# basic datasets description
data.describe()
# Out:
#               year  malaria_incidence_per_1000_at_risk  \
# count  1226.000000                         1226.000000
# mean   2012.007341                          202.196120
# std       7.215682                          159.520600
# min    2000.000000                            0.000000
# 25%    2006.000000                           45.052028
# 50%    2012.000000                          213.708044
# 75%    2018.000000                          339.645518
# max    2024.000000                          711.438315
#
#        health_expenditure_per_capita_usd  rural_population_pct  \
# count                        1137.000000           1226.000000
# mean                           87.790748             58.359746
# std                           111.810461             17.326137
# min                             4.175786              8.136791
# 25%                            25.935120             45.783679
# 50%                            47.438931             60.074106
# 75%                            84.223167             71.141920
# max                           686.872437             91.956186
#
#        gdp_per_capita_usd  population_total  forest_area_pct  \
# count         1196.000000      1.226000e+03      1153.000000
# mean          1825.873141      2.289159e+07        29.845705
# std           2173.457485      3.239419e+07        24.508511
# min            109.593814      1.440180e+05         0.045186
# 25%            545.946835      3.152732e+06        10.889408
# 50%            985.640839      1.259106e+07        24.000146
# 75%           2157.916840      2.821292e+07        45.383369
# max          18210.555297      2.326795e+08        93.247059
#
#        population_density  under5_mortality_per_1000  life_expectancy_years  \
# count         1153.000000                1226.000000            1226.000000
# mean            83.339955                  85.932219              59.640477
# std            100.672487                  46.387866               6.913734
# min              2.208999                  11.100000              14.665000
# 25%             19.982611                  51.525000              55.234250
# 50%             49.133282                  77.250000              59.965500
# 75%             97.974438                 113.500000              63.958000
# max            634.118177                 489.300000              76.475000
#
#        basic_water_access_pct  urban_population_pct  govt_health_exp_pct_gdp  \
# count             1197.000000           1226.000000              1137.000000
# mean                63.520261             41.640254                 1.530108
# std                 16.829602             17.326137                 1.124640
# min                 18.759061              8.043814                 0.062210
# 25%                 51.252303             28.858080                 0.757137
# 50%                 63.003111             39.925894                 1.221417
# 75%                 76.277061             54.216321                 1.881071
# max                 99.853747             91.863209                 6.518854
#
#        primary_completion_rate_pct  fertility_rate_births_per_woman
# count                   741.000000                      1226.000000
# mean                     66.678659                         4.777020
# std                      20.875997                         1.257107
# min                      15.692990                         1.420000
# 25%                      54.036289                         3.950500
# 50%                      65.206451                         4.840500
# 75%                      84.310328                         5.642500
# max                     114.697441                         7.829000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso3                                1226 non-null   object
#  1   year                                1226 non-null   int64
#  2   malaria_incidence_per_1000_at_risk  1226 non-null   float64
#  3   health_expenditure_per_capita_usd   1137 non-null   float64
#  4   rural_population_pct                1226 non-null   float64
#  5   gdp_per_capita_usd                  1196 non-null   float64
#  6   population_total                    1226 non-null   int64
#  7   forest_area_pct                     1153 non-null   float64
#  8   population_density                  1153 non-null   float64
#  9   under5_mortality_per_1000           1226 non-null   float64
#  10  life_expectancy_years               1226 non-null   float64
#  11  basic_water_access_pct              1197 non-null   float64
#  12  urban_population_pct                1226 non-null   float64
#  13  govt_health_exp_pct_gdp             1137 non-null   float64
#  14  primary_completion_rate_pct         741 non-null    float64
#  15  fertility_rate_births_per_woman     1226 non-null   float64
#  16  country                             1226 non-null   object
# dtypes: float64(13), int64(2), object(2)
# memory usage: 163.0+ KB

# %%
# check different values inside country column
country_count = data["country"].value_counts()
country_count
# Out:
# country
# Eritrea                     25
# Gabon                       25
# Cabo Verde                  25
# Rwanda                      25
# Ghana                       25
# South Africa                25
# Kenya                       25
# Botswana                    25
# Eswatini                    25
# Egypt, Arab Rep.            25
# Tanzania                    25
# Namibia                     25
# Somalia, Fed. Rep.          25
# Sao Tome and Principe       25
# Malawi                      25
# Mozambique                  25
# Burundi                     25
# Niger                       25
# Burkina Faso                25
# Chad                        25
# Guinea-Bissau               25
# Congo, Dem. Rep.            25
# Guinea                      25
# Angola                      25
# South Sudan                 25
# Morocco                     25
# Cote d'Ivoire               25
# Madagascar                  25
# Ethiopia                    25
# Liberia                     25
# Congo, Rep.                 25
# Sudan                       25
# Cameroon                    25
# Togo                        25
# Algeria                     25
# Benin                       25
# Gambia, The                 25
# Sierra Leone                25
# Nigeria                     25
# Mali                        25
# Comoros                     25
# Djibouti                    25
# Senegal                     25
# Equatorial Guinea           25
# Zimbabwe                    25
# Uganda                      25
# Central African Republic    25
# Zambia                      25
# Mauritania                  25
# Mauritius                    1
# Name: count, dtype: int64

# %%
# check number of missing values
nan_values = data.isna().sum()
missing_values_table = pd.DataFrame({
    "Missing Values": nan_values,
    "Ratio Missing Values (%)": (nan_values/len(data))*100
})
missing_values_table = (
    missing_values_table
    .sort_values(by="Ratio Missing Values (%)", ascending=False)
    .round({"Ratio Missing Values (%)":2})
    .reset_index()
    .rename(columns={"index":"Column Name"})
)
missing_values_table
# Out:
#                            Column Name  Missing Values  \
# 0          primary_completion_rate_pct             485
# 1              govt_health_exp_pct_gdp              89
# 2    health_expenditure_per_capita_usd              89
# 3                      forest_area_pct              73
# 4                   population_density              73
# 5                   gdp_per_capita_usd              30
# 6               basic_water_access_pct              29
# 7                                 iso3               0
# 8                 rural_population_pct               0
# 9                     population_total               0
# 10                                year               0
# 11  malaria_incidence_per_1000_at_risk               0
# 12           under5_mortality_per_1000               0
# 13                urban_population_pct               0
# 14               life_expectancy_years               0
# 15     fertility_rate_births_per_woman               0
# 16                             country               0
#
#     Ratio Missing Values (%)
# 0                      39.56
# 1                       7.26
# 2                       7.26
# 3                       5.95
# 4                       5.95
# 5                       2.45
# 6                       2.37
# 7                       0.00
# 8                       0.00
# 9                       0.00
# 10                      0.00
# 11                      0.00
# 12                      0.00
# 13                      0.00
# 14                      0.00
# 15                      0.00
# 16                      0.00

# %% [markdown]
# ### Build heatmap to see how features relate with the target value (malaria_incidence_per_1000_at_rist)

# %%
features = [
    "malaria_incidence_per_1000_at_risk",
    "year",
    "health_expenditure_per_capita_usd",
    "rural_population_pct",
    "gdp_per_capita_usd",
    "population_total",
    "forest_area_pct",
    "population_density",
    "under5_mortality_per_1000",
    "life_expectancy_years",
    "basic_water_access_pct",
    "urban_population_pct",
    "govt_health_exp_pct_gdp",
    "primary_completion_rate_pct",
    "fertility_rate_births_per_woman",
]

corr = data[features].corr()

# Plot
plt.figure(figsize=(14, 10))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1,
    vmax=1,
    center=0,
    square=True,
    linewidths=0.5,
    annot_kws={"size": 8},
    cbar_kws={"shrink": 0.8}
)

plt.title("Malaria Cases Feature Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
# handling missing values with the mean of each column
clean_data = data.copy()

numeric_cols = clean_data.select_dtypes(include=np.number).columns

clean_data[numeric_cols] = clean_data[numeric_cols].fillna(
    clean_data[numeric_cols].mean()
)
clean_data.isna().sum()
# Out:
# iso3                                  0
# year                                  0
# malaria_incidence_per_1000_at_risk    0
# health_expenditure_per_capita_usd     0
# rural_population_pct                  0
# gdp_per_capita_usd                    0
# population_total                      0
# forest_area_pct                       0
# population_density                    0
# under5_mortality_per_1000             0
# life_expectancy_years                 0
# basic_water_access_pct                0
# urban_population_pct                  0
# govt_health_exp_pct_gdp               0
# primary_completion_rate_pct           0
# fertility_rate_births_per_woman       0
# country                               0
# dtype: int64

# %%
# compute heatmap after cleaning NAN values
features = [
    "malaria_incidence_per_1000_at_risk",
    "year",
    "health_expenditure_per_capita_usd",
    "rural_population_pct",
    "gdp_per_capita_usd",
    "population_total",
    "forest_area_pct",
    "population_density",
    "under5_mortality_per_1000",
    "life_expectancy_years",
    "basic_water_access_pct",
    "urban_population_pct",
    "govt_health_exp_pct_gdp",
    "primary_completion_rate_pct",
    "fertility_rate_births_per_woman",
]

corr = clean_data[features].corr()

# Plot
plt.figure(figsize=(14, 10))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1,
    vmax=1,
    center=0,
    square=True,
    linewidths=0.5,
    annot_kws={"size": 8},
    cbar_kws={"shrink": 0.8}
)

plt.title("Malaria Cases Feature Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
col = "primary_completion_rate_pct"
data_sorted = data.sort_values(["country", "year"])

# global mean
global_mean_fill = data_sorted[col].fillna(data_sorted[col].mean())

# Approach B: within-country linear interpolation
interpolated_fill = (
    data_sorted.groupby("country")[col]
    .apply(lambda s: s.interpolate(method="linear", limit_direction="both"))
)
interpolated_fill.index = data_sorted.index

print("Missing before:", data_sorted[col].isna().sum())
print("Missing after interpolation:", interpolated_fill.isna().sum())
# Out:
# Missing before: 485
# Missing after interpolation: 50

# %%
print("Standard deviation, original data only: ", round(data_sorted[col].std(), 2))
print("Standard deviation, after filling wih global mean: ", round(global_mean_fill.std(), 2))
print("Standard deviation, after interpolating: ", round(interpolated_fill.std(), 2))
# Out:
# Standard deviation, original data only:  20.88
# Standard deviation, after filling wih global mean:  16.23
# Standard deviation, after interpolating:  20.76

# %%
target = "malaria_incidence_per_1000_at_risk"

real_only_corr = data_sorted[[target, col]].corr().iloc[0, 1]

df_mean = data_sorted.copy()
df_mean[col] = global_mean_fill

df_interp = data_sorted.copy()
df_interp[col] = interpolated_fill

print("Real data only:    ", round(data_sorted[[target, col]].corr().iloc[0, 1], 3))
print("Global mean fill:  ", round(df_mean[[target, col]].corr().iloc[0, 1], 3))
print("Interpolated fill: ", round(df_interp[[target, col]].corr().iloc[0, 1], 3))
# Out:
# Real data only:     -0.563
# Global mean fill:   -0.46
# Interpolated fill:  -0.55

# %%
# missing values by country
missing_by_country = data.groupby("country").apply(lambda df: df.isna().sum())

missing_by_country
# Out:
# /tmp/ipykernel_111248/2802256112.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_by_country = data.groupby("country").apply(lambda df: df.isna().sum())
#                           iso3  year  malaria_incidence_per_1000_at_risk  \
# country
# Algeria                      0     0                                   0
# Angola                       0     0                                   0
# Benin                        0     0                                   0
# Botswana                     0     0                                   0
# Burkina Faso                 0     0                                   0
# Burundi                      0     0                                   0
# Cabo Verde                   0     0                                   0
# Cameroon                     0     0                                   0
# Central African Republic     0     0                                   0
# Chad                         0     0                                   0
# Comoros                      0     0                                   0
# Congo, Dem. Rep.             0     0                                   0
# Congo, Rep.                  0     0                                   0
# Cote d'Ivoire                0     0                                   0
# Djibouti                     0     0                                   0
# Egypt, Arab Rep.             0     0                                   0
# Equatorial Guinea            0     0                                   0
# Eritrea                      0     0                                   0
# Eswatini                     0     0                                   0
# Ethiopia                     0     0                                   0
# Gabon                        0     0                                   0
# Gambia, The                  0     0                                   0
# Ghana                        0     0                                   0
# Guinea                       0     0                                   0
# Guinea-Bissau                0     0                                   0
# Kenya                        0     0                                   0
# Liberia                      0     0                                   0
# Madagascar                   0     0                                   0
# Malawi                       0     0                                   0
# Mali                         0     0                                   0
# Mauritania                   0     0                                   0
# Mauritius                    0     0                                   0
# Morocco                      0     0                                   0
# Mozambique                   0     0                                   0
# Namibia                      0     0                                   0
# Niger                        0     0                                   0
# Nigeria                      0     0                                   0
# Rwanda                       0     0                                   0
# Sao Tome and Principe        0     0                                   0
# Senegal                      0     0                                   0
# Sierra Leone                 0     0                                   0
# Somalia, Fed. Rep.           0     0                                   0
# South Africa                 0     0                                   0
# South Sudan                  0     0                                   0
# Sudan                        0     0                                   0
# Tanzania                     0     0                                   0
# Togo                         0     0                                   0
# Uganda                       0     0                                   0
# Zambia                       0     0                                   0
# Zimbabwe                     0     0                                   0
#
#                           health_expenditure_per_capita_usd  \
# country
# Algeria                                                   1
# Angola                                                    1
# Benin                                                     1
# Botswana                                                  1
# Burkina Faso                                              1
# Burundi                                                   1
# Cabo Verde                                                1
# Cameroon                                                  1
# Central African Republic                                  1
# Chad                                                      1
# Comoros                                                   1
# Congo, Dem. Rep.                                          1
# Congo, Rep.                                               1
# Cote d'Ivoire                                             1
# Djibouti                                                  1
# Egypt, Arab Rep.                                          1
# Equatorial Guinea                                         1
# Eritrea                                                   1
# Eswatini                                                  1
# Ethiopia                                                  1
# Gabon                                                     1
# Gambia, The                                               1
# Ghana                                                     1
# Guinea                                                    1
# Guinea-Bissau                                             1
# Kenya                                                     1
# Liberia                                                   1
# Madagascar                                                1
# Malawi                                                    1
# Mali                                                      1
# Mauritania                                                1
# Mauritius                                                 0
# Morocco                                                   1
# Mozambique                                                1
# Namibia                                                   1
# Niger                                                     1
# Nigeria                                                   1
# Rwanda                                                    1
# Sao Tome and Principe                                     1
# Senegal                                                   1
# Sierra Leone                                              1
# Somalia, Fed. Rep.                                       14
# South Africa                                              1
# South Sudan                                              18
# Sudan                                                     1
# Tanzania                                                  1
# Togo                                                      1
# Uganda                                                    1
# Zambia                                                    1
# Zimbabwe                                                 11
#
#                           rural_population_pct  gdp_per_capita_usd  \
# country
# Algeria                                      0                   0
# Angola                                       0                   0
# Benin                                        0                   0
# Botswana                                     0                   0
# Burkina Faso                                 0                   0
# Burundi                                      0                   0
# Cabo Verde                                   0                   0
# Cameroon                                     0                   0
# Central African Republic                     0                   0
# Chad                                         0                   0
# Comoros                                      0                   0
# Congo, Dem. Rep.                             0                   0
# Congo, Rep.                                  0                   0
# Cote d'Ivoire                                0                   0
# Djibouti                                     0                   0
# Egypt, Arab Rep.                             0                   0
# Equatorial Guinea                            0                   0
# Eritrea                                      0                  13
# Eswatini                                     0                   0
# Ethiopia                                     0                   0
# Gabon                                        0                   0
# Gambia, The                                  0                   0
# Ghana                                        0                   0
# Guinea                                       0                   0
# Guinea-Bissau                                0                   0
# Kenya                                        0                   0
# Liberia                                      0                   0
# Madagascar                                   0                   0
# Malawi                                       0                   0
# Mali                                         0                   0
# Mauritania                                   0                   0
# Mauritius                                    0                   0
# Morocco                                      0                   0
# Mozambique                                   0                   0
# Namibia                                      0                   0
# Niger                                        0                   0
# Nigeria                                      0                   0
# Rwanda                                       0                   0
# Sao Tome and Principe                        0                   0
# Senegal                                      0                   0
# Sierra Leone                                 0                   0
# Somalia, Fed. Rep.                           0                   0
# South Africa                                 0                   0
# South Sudan                                  0                  17
# Sudan                                        0                   0
# Tanzania                                     0                   0
# Togo                                         0                   0
# Uganda                                       0                   0
# Zambia                                       0                   0
# Zimbabwe                                     0                   0
#
#                           population_total  forest_area_pct  \
# country
# Algeria                                  0                1
# Angola                                   0                1
# Benin                                    0                1
# Botswana                                 0                1
# Burkina Faso                             0                1
# Burundi                                  0                1
# Cabo Verde                               0                1
# Cameroon                                 0                1
# Central African Republic                 0                1
# Chad                                     0                1
# Comoros                                  0                1
# Congo, Dem. Rep.                         0                1
# Congo, Rep.                              0                1
# Cote d'Ivoire                            0                1
# Djibouti                                 0                1
# Egypt, Arab Rep.                         0                1
# Equatorial Guinea                        0                1
# Eritrea                                  0                1
# Eswatini                                 0                1
# Ethiopia                                 0                1
# Gabon                                    0                1
# Gambia, The                              0                1
# Ghana                                    0                1
# Guinea                                   0                1
# Guinea-Bissau                            0                1
# Kenya                                    0                1
# Liberia                                  0                1
# Madagascar                               0                1
# Malawi                                   0                1
# Mali                                     0                1
# Mauritania                               0                1
# Mauritius                                0                0
# Morocco                                  0                1
# Mozambique                               0                1
# Namibia                                  0                1
# Niger                                    0                1
# Nigeria                                  0                1
# Rwanda                                   0                1
# Sao Tome and Principe                    0                1
# Senegal                                  0                1
# Sierra Leone                             0                1
# Somalia, Fed. Rep.                       0                1
# South Africa                             0                1
# South Sudan                              0               13
# Sudan                                    0               13
# Tanzania                                 0                1
# Togo                                     0                1
# Uganda                                   0                1
# Zambia                                   0                1
# Zimbabwe                                 0                1
#
#                           population_density  under5_mortality_per_1000  \
# country
# Algeria                                    1                          0
# Angola                                     1                          0
# Benin                                      1                          0
# Botswana                                   1                          0
# Burkina Faso                               1                          0
# Burundi                                    1                          0
# Cabo Verde                                 1                          0
# Cameroon                                   1                          0
# Central African Republic                   1                          0
# Chad                                       1                          0
# Comoros                                    1                          0
# Congo, Dem. Rep.                           1                          0
# Congo, Rep.                                1                          0
# Cote d'Ivoire                              1                          0
# Djibouti                                   1                          0
# Egypt, Arab Rep.                           1                          0
# Equatorial Guinea                          1                          0
# Eritrea                                    1                          0
# Eswatini                                   1                          0
# Ethiopia                                   1                          0
# Gabon                                      1                          0
# Gambia, The                                1                          0
# Ghana                                      1                          0
# Guinea                                     1                          0
# Guinea-Bissau                              1                          0
# Kenya                                      1                          0
# Liberia                                    1                          0
# Madagascar                                 1                          0
# Malawi                                     1                          0
# Mali                                       1                          0
# Mauritania                                 1                          0
# Mauritius                                  0                          0
# Morocco                                    1                          0
# Mozambique                                 1                          0
# Namibia                                    1                          0
# Niger                                      1                          0
# Nigeria                                    1                          0
# Rwanda                                     1                          0
# Sao Tome and Principe                      1                          0
# Senegal                                    1                          0
# Sierra Leone                               1                          0
# Somalia, Fed. Rep.                         1                          0
# South Africa                               1                          0
# South Sudan                               13                          0
# Sudan                                     13                          0
# Tanzania                                   1                          0
# Togo                                       1                          0
# Uganda                                     1                          0
# Zambia                                     1                          0
# Zimbabwe                                   1                          0
#
#                           life_expectancy_years  basic_water_access_pct  \
# country
# Algeria                                       0                       0
# Angola                                        0                       0
# Benin                                         0                       0
# Botswana                                      0                       0
# Burkina Faso                                  0                       0
# Burundi                                       0                       0
# Cabo Verde                                    0                       0
# Cameroon                                      0                       0
# Central African Republic                      0                       0
# Chad                                          0                       0
# Comoros                                       0                       0
# Congo, Dem. Rep.                              0                       0
# Congo, Rep.                                   0                       3
# Cote d'Ivoire                                 0                       0
# Djibouti                                      0                       0
# Egypt, Arab Rep.                              0                       0
# Equatorial Guinea                             0                       7
# Eritrea                                       0                       8
# Eswatini                                      0                       0
# Ethiopia                                      0                       0
# Gabon                                         0                       0
# Gambia, The                                   0                       0
# Ghana                                         0                       0
# Guinea                                        0                       0
# Guinea-Bissau                                 0                       0
# Kenya                                         0                       0
# Liberia                                       0                       0
# Madagascar                                    0                       0
# Malawi                                        0                       0
# Mali                                          0                       0
# Mauritania                                    0                       0
# Mauritius                                     0                       0
# Morocco                                       0                       0
# Mozambique                                    0                       0
# Namibia                                       0                       0
# Niger                                         0                       0
# Nigeria                                       0                       0
# Rwanda                                        0                       0
# Sao Tome and Principe                         0                       0
# Senegal                                       0                       0
# Sierra Leone                                  0                       0
# Somalia, Fed. Rep.                            0                       0
# South Africa                                  0                       0
# South Sudan                                   0                      11
# Sudan                                         0                       0
# Tanzania                                      0                       0
# Togo                                          0                       0
# Uganda                                        0                       0
# Zambia                                        0                       0
# Zimbabwe                                      0                       0
#
#                           urban_population_pct  govt_health_exp_pct_gdp  \
# country
# Algeria                                      0                        1
# Angola                                       0                        1
# Benin                                        0                        1
# Botswana                                     0                        1
# Burkina Faso                                 0                        1
# Burundi                                      0                        1
# Cabo Verde                                   0                        1
# Cameroon                                     0                        1
# Central African Republic                     0                        1
# Chad                                         0                        1
# Comoros                                      0                        1
# Congo, Dem. Rep.                             0                        1
# Congo, Rep.                                  0                        1
# Cote d'Ivoire                                0                        1
# Djibouti                                     0                        1
# Egypt, Arab Rep.                             0                        1
# Equatorial Guinea                            0                        1
# Eritrea                                      0                        1
# Eswatini                                     0                        1
# Ethiopia                                     0                        1
# Gabon                                        0                        1
# Gambia, The                                  0                        1
# Ghana                                        0                        1
# Guinea                                       0                        1
# Guinea-Bissau                                0                        1
# Kenya                                        0                        1
# Liberia                                      0                        1
# Madagascar                                   0                        1
# Malawi                                       0                        1
# Mali                                         0                        1
# Mauritania                                   0                        1
# Mauritius                                    0                        0
# Morocco                                      0                        1
# Mozambique                                   0                        1
# Namibia                                      0                        1
# Niger                                        0                        1
# Nigeria                                      0                        1
# Rwanda                                       0                        1
# Sao Tome and Principe                        0                        1
# Senegal                                      0                        1
# Sierra Leone                                 0                        1
# Somalia, Fed. Rep.                           0                       14
# South Africa                                 0                        1
# South Sudan                                  0                       18
# Sudan                                        0                        1
# Tanzania                                     0                        1
# Togo                                         0                        1
# Uganda                                       0                        1
# Zambia                                       0                        1
# Zimbabwe                                     0                       11
#
#                           primary_completion_rate_pct  \
# country
# Algeria                                             0
# Angola                                             19
# Benin                                               8
# Botswana                                           12
# Burkina Faso                                        1
# Burundi                                             5
# Cabo Verde                                          2
# Cameroon                                            5
# Central African Republic                           16
# Chad                                                8
# Comoros                                            14
# Congo, Dem. Rep.                                   13
# Congo, Rep.                                        12
# Cote d'Ivoire                                       6
# Djibouti                                           25
# Egypt, Arab Rep.                                    6
# Equatorial Guinea                                  16
# Eritrea                                             7
# Eswatini                                            4
# Ethiopia                                            6
# Gabon                                              23
# Gambia, The                                         2
# Ghana                                               5
# Guinea                                              9
# Guinea-Bissau                                      23
# Kenya                                              20
# Liberia                                            16
# Madagascar                                          0
# Malawi                                              7
# Mali                                                6
# Mauritania                                         11
# Mauritius                                           0
# Morocco                                             0
# Mozambique                                          5
# Namibia                                             3
# Niger                                               4
# Nigeria                                            17
# Rwanda                                              6
# Sao Tome and Principe                              12
# Senegal                                             3
# Sierra Leone                                       11
# Somalia, Fed. Rep.                                 25
# South Africa                                       13
# South Sudan                                        24
# Sudan                                              16
# Tanzania                                            4
# Togo                                                3
# Uganda                                             10
# Zambia                                             13
# Zimbabwe                                            9
#
#                           fertility_rate_births_per_woman  country
# country
# Algeria                                                 0        0
# Angola                                                  0        0
# Benin                                                   0        0
# Botswana                                                0        0
# Burkina Faso                                            0        0
# Burundi                                                 0        0
# Cabo Verde                                              0        0
# Cameroon                                                0        0
# Central African Republic                                0        0
# Chad                                                    0        0
# Comoros                                                 0        0
# Congo, Dem. Rep.                                        0        0
# Congo, Rep.                                             0        0
# Cote d'Ivoire                                           0        0
# Djibouti                                                0        0
# Egypt, Arab Rep.                                        0        0
# Equatorial Guinea                                       0        0
# Eritrea                                                 0        0
# Eswatini                                                0        0
# Ethiopia                                                0        0
# Gabon                                                   0        0
# Gambia, The                                             0        0
# Ghana                                                   0        0
# Guinea                                                  0        0
# Guinea-Bissau                                           0        0
# Kenya                                                   0        0
# Liberia                                                 0        0
# Madagascar                                              0        0
# Malawi                                                  0        0
# Mali                                                    0        0
# Mauritania                                              0        0
# Mauritius                                               0        0
# Morocco                                                 0        0
# Mozambique                                              0        0
# Namibia                                                 0        0
# Niger                                                   0        0
# Nigeria                                                 0        0
# Rwanda                                                  0        0
# Sao Tome and Principe                                   0        0
# Senegal                                                 0        0
# Sierra Leone                                            0        0
# Somalia, Fed. Rep.                                      0        0
# South Africa                                            0        0
# South Sudan                                             0        0
# Sudan                                                   0        0
# Tanzania                                                0        0
# Togo                                                    0        0
# Uganda                                                  0        0
# Zambia                                                  0        0
# Zimbabwe                                                0        0

# %% [markdown]
# ### The missing data in primary_completion_rate_pct column after interpolation comes from two countries Djibouti and Somalia, Fed. Rep. with No values since 2000 to 2025. In fact, there is no available data reported for those countries. Thus, interpolation failed. Because of the complete lack of information, the two countries will not be considered in our model. Fix and apply the same interpolation pattern in all the columns with missing values

# %%
other_cols = [
    "health_expenditure_per_capita_usd", "govt_health_exp_pct_gdp", "gdp_per_capita_usd",
    "forest_area_pct", "population_density", "basic_water_access_pct", "life_expectancy_years",
    "rural_population_pct", "fertility_rate_births_per_woman", "under5_mortality_per_1000",
    "urban_population_pct", "population_total",
]

clean_data_interp = data_sorted.copy()

for columns in other_cols:
    clean_data_interp[columns] = (
        data_sorted.groupby("country")[columns]
        .apply(lambda s: s.interpolate(method="linear", limit_direction="both"))
        .values
    )
clean_data_interp
# Out:
#      iso3  year  malaria_incidence_per_1000_at_risk  \
# 329   DZA  2000                            0.018730
# 267   DZA  2001                            0.003260
# 435   DZA  2002                            0.005362
# 121   DZA  2003                            0.002645
# 589   DZA  2004                            0.001044
# ...   ...   ...                                 ...
# 717   ZWE  2020                           94.296872
# 1134  ZWE  2021                           27.537495
# 985   ZWE  2022                           28.901366
# 859   ZWE  2023                           49.396046
# 1198  ZWE  2024                           11.362725
#
#       health_expenditure_per_capita_usd  rural_population_pct  \
# 329                           61.857853             40.147876
# 267                           67.058594             39.382283
# 435                           66.681633             38.618734
# 121                           75.951309             37.857209
# 589                           92.687630             37.097687
# ...                                 ...                   ...
# 717                           51.142506             62.990233
# 1134                          60.898743             62.130794
# 985                           68.907280             61.294479
# 859                           62.929462             60.708063
# 1198                          62.929462             60.106628
#
#       gdp_per_capita_usd  population_total  forest_area_pct  \
# 329          1772.928691          30903893         0.662961
# 267          1896.300209          31331221         0.677194
# 435          1937.464114          31750835         0.691427
# 121          2283.772993          32175818         0.705661
# 589          2816.993850          32628286         0.719894
# ...                  ...               ...              ...
# 717          2059.637040          15526888        45.093912
# 1134         2613.616741          15797210        44.974822
# 985          2536.401971          16069056        44.855732
# 859          2195.225020          16340822        44.736642
# 1198         2496.155150          16634373        44.736642
#
#       population_density  under5_mortality_per_1000  life_expectancy_years  \
# 329            12.975343                       41.7                 70.576
# 267            13.154761                       40.2                 71.025
# 435            13.330941                       38.6                 71.644
# 121            13.509375                       37.0                 71.906
# 589            13.699348                       35.4                 72.536
# ...                  ...                        ...                    ...
# 717            40.136714                       61.7                 61.530
# 1134           40.835492                       62.4                 60.135
# 985            41.538209                       64.0                 62.360
# 859            42.240719                       64.2                 62.775
# 1198           42.240719                       64.7                 63.064
#
#       basic_water_access_pct  urban_population_pct  govt_health_exp_pct_gdp  \
# 329                88.993808             59.852124                 2.313520
# 267                89.169802             60.617717                 2.695605
# 435                89.343640             61.381266                 2.590863
# 121                89.515109             62.142791                 2.550614
# 589                89.684221             62.902313                 2.347748
# ...                      ...                   ...                      ...
# 717                67.166424             37.009767                 0.652689
# 1134               67.162605             37.869206                 0.879811
# 985                67.168908             38.705521                 1.018298
# 859                67.184919             39.291937                 0.946628
# 1198               67.211021             39.893372                 0.946628
#
#       primary_completion_rate_pct  fertility_rate_births_per_woman   country
# 329                     81.979156                            2.590   Algeria
# 267                     89.100311                            2.519   Algeria
# 435                     91.904259                            2.429   Algeria
# 121                     94.512001                            2.451   Algeria
# 589                     96.502480                            2.500   Algeria
# ...                           ...                              ...       ...
# 717                     88.343367                            3.754  Zimbabwe
# 1134                    83.033886                            3.765  Zimbabwe
# 985                     83.198409                            3.767  Zimbabwe
# 859                     85.202932                            3.724  Zimbabwe
# 1198                    85.960763                            3.674  Zimbabwe
#
# [1226 rows x 17 columns]

# %%
# drop Djibouti and Somalia, Fed. Rep. with the reason provided above
clean_data_interp["primary_completion_rate_pct"] = interpolated_fill.values
clean_data_interp = clean_data_interp[~clean_data_interp["country"].isin(["Djibouti", "Somalia, Fed. Rep."])]

clean_data_interp.isna().sum()
# Out:
# iso3                                  0
# year                                  0
# malaria_incidence_per_1000_at_risk    0
# health_expenditure_per_capita_usd     0
# rural_population_pct                  0
# gdp_per_capita_usd                    0
# population_total                      0
# forest_area_pct                       0
# population_density                    0
# under5_mortality_per_1000             0
# life_expectancy_years                 0
# basic_water_access_pct                0
# urban_population_pct                  0
# govt_health_exp_pct_gdp               0
# primary_completion_rate_pct           0
# fertility_rate_births_per_woman       0
# country                               0
# dtype: int64

# %%
# compute heatmap after interpolating NAN values and removing Djibouti and Somalia, Fed. Rep
features = [
    "malaria_incidence_per_1000_at_risk",
    "year",
    "health_expenditure_per_capita_usd",
    "rural_population_pct",
    "gdp_per_capita_usd",
    "population_total",
    "forest_area_pct",
    "population_density",
    "under5_mortality_per_1000",
    "life_expectancy_years",
    "basic_water_access_pct",
    "urban_population_pct",
    "govt_health_exp_pct_gdp",
    "primary_completion_rate_pct",
    "fertility_rate_births_per_woman",
]

corr = clean_data_interp[features].corr()

# Plot
plt.figure(figsize=(14, 10))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1,
    vmax=1,
    center=0,
    square=True,
    linewidths=0.5,
    annot_kws={"size": 8},
    cbar_kws={"shrink": 0.8}
)

plt.title("Malaria Cases Feature Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### For my model, country and ISO3 will be removed. Also, rural_population_pct and urban_population_pct have a collinearity of -1. This is because the rural_population_pct is just the probability complement of urban_population_pct. The two features carry the same information. However, for epidemiological reasons, more specifically, I want to analyze how the number of malaria cases increase or decrease when there is a high concentration of the population in rural area, I will keep rural_population_pct and drop urban_population_pct.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

feature_cols = [
    "year", "health_expenditure_per_capita_usd", "gdp_per_capita_usd", "population_total",
    "forest_area_pct", "population_density", "under5_mortality_per_1000", "life_expectancy_years",
    "basic_water_access_pct", "rural_population_pct", "govt_health_exp_pct_gdp",
    "primary_completion_rate_pct", "fertility_rate_births_per_woman",
] 

X = add_constant(clean_data_interp[feature_cols])

vif = pd.DataFrame()
vif["feature"] = X.columns
vif["Variance Inflation Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif = vif[vif["feature"] != "const"].sort_values("Variance Inflation Factor", ascending=False)
vif
# Out:
#                               feature  Variance Inflation Factor
# 2   health_expenditure_per_capita_usd                   7.442476
# 7           under5_mortality_per_1000                   6.600402
# 8               life_expectancy_years                   5.926777
# 3                  gdp_per_capita_usd                   4.047557
# 13    fertility_rate_births_per_woman                   3.920566
# 10               rural_population_pct                   3.287902
# 11            govt_health_exp_pct_gdp                   3.271402
# 9              basic_water_access_pct                   3.267674
# 12        primary_completion_rate_pct                   2.792364
# 5                     forest_area_pct                   1.810293
# 1                                year                   1.412582
# 6                  population_density                   1.338295
# 4                    population_total                   1.175467

# %% [markdown]
# ### Moreover, although population_total and population_densisty all have near zero collinearity with our target, population_density will be kept while population_total will be removed. In fact, malaria spreads through mosquito bites, so transmission depends on how much contact happens between people and mosquito breeding sites, and between infected and uninfected people. That contact rate is driven by how packed together people and breeding sites are, not by how many people exist in the country overall. For instance, two countries can have the same total population but very different transmission dynamics if one is spread thin across a huge area and the other is concentrated. In that case, density is a proxy for exposure/contact rate; raw population count is not. Therefore, population_density will be kept in our model and population_total will be rmeoved.

# %%
columns_to_drop = ["iso3", "country", "urban_population_pct", "population_total"]
model_data = clean_data_interp.drop(columns=columns_to_drop, axis=1)
model_data.head()
# Out:
#      year  malaria_incidence_per_1000_at_risk  \
# 329  2000                            0.018730
# 267  2001                            0.003260
# 435  2002                            0.005362
# 121  2003                            0.002645
# 589  2004                            0.001044
#
#      health_expenditure_per_capita_usd  rural_population_pct  \
# 329                          61.857853             40.147876
# 267                          67.058594             39.382283
# 435                          66.681633             38.618734
# 121                          75.951309             37.857209
# 589                          92.687630             37.097687
#
#      gdp_per_capita_usd  forest_area_pct  population_density  \
# 329         1772.928691         0.662961           12.975343
# 267         1896.300209         0.677194           13.154761
# 435         1937.464114         0.691427           13.330941
# 121         2283.772993         0.705661           13.509375
# 589         2816.993850         0.719894           13.699348
#
#      under5_mortality_per_1000  life_expectancy_years  basic_water_access_pct  \
# 329                       41.7                 70.576               88.993808
# 267                       40.2                 71.025               89.169802
# 435                       38.6                 71.644               89.343640
# 121                       37.0                 71.906               89.515109
# 589                       35.4                 72.536               89.684221
#
#      govt_health_exp_pct_gdp  primary_completion_rate_pct  \
# 329                 2.313520                    81.979156
# 267                 2.695605                    89.100311
# 435                 2.590863                    91.904259
# 121                 2.550614                    94.512001
# 589                 2.347748                    96.502480
#
#      fertility_rate_births_per_woman
# 329                            2.590
# 267                            2.519
# 435                            2.429
# 121                            2.451
# 589                            2.500

# %%
model_data.shape
# Out:
# (1176, 13)

# %%
model_data.columns
# Out:
# Index(['year', 'malaria_incidence_per_1000_at_risk',
#        'health_expenditure_per_capita_usd', 'rural_population_pct',
#        'gdp_per_capita_usd', 'forest_area_pct', 'population_density',
#        'under5_mortality_per_1000', 'life_expectancy_years',
#        'basic_water_access_pct', 'govt_health_exp_pct_gdp',
#        'primary_completion_rate_pct', 'fertility_rate_births_per_woman'],
#       dtype='object')

# %%
# choosing features and target
features_columns = ['health_expenditure_per_capita_usd', 'rural_population_pct',
       'gdp_per_capita_usd', 'forest_area_pct', 'population_density',
       'under5_mortality_per_1000', 'life_expectancy_years',
       'basic_water_access_pct', 'govt_health_exp_pct_gdp',
       'primary_completion_rate_pct', 'fertility_rate_births_per_woman'
       ]
target_column = "malaria_incidence_per_1000_at_risk"

# %%
# random 80/20 split (replaces the year-based split)
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(model_data, test_size=0.2, random_state=42)

# %%
print(f"Train dataset shape: {train_data.shape}")
print(f"Test dataset shape: {test_data.shape}")
# Out:
# Train dataset shape: (940, 13)
# Test dataset shape: (236, 13)

# %%
# training and test data (exclude year)
X_train = train_data[features_columns]
X_test = test_data[features_columns]
Y_train = train_data[target_column]
Y_test = test_data[target_column]

# %%
X_test.head()
# Out:
#       health_expenditure_per_capita_usd  rural_population_pct  \
# 1194                          29.724831             77.025824
# 815                           56.608055             57.413891
# 1058                         258.018738             40.357877
# 670                           75.553322             36.337324
# 16                            71.209946             43.587153
#
#       gdp_per_capita_usd  forest_area_pct  population_density  \
# 1194          514.684451        25.096857           54.153169
# 815           679.665387        71.613442           65.145555
# 1058         5291.583791        29.839430            3.307600
# 670          2477.978455        64.131772           18.105081
# 16            663.696212        60.710417          160.222917
#
#       under5_mortality_per_1000  life_expectancy_years  \
# 1194                      138.1                 54.377
# 815                        88.2                 60.619
# 1058                       66.0                 55.112
# 670                        40.3                 65.772
# 16                         65.7                 62.158
#
#       basic_water_access_pct  govt_health_exp_pct_gdp  \
# 1194               54.477512                 1.432129
# 815                60.649894                 0.484643
# 1058               77.379375                 2.791103
# 670                73.488421                 1.120951
# 16                 70.592859                 6.054948
#
#       primary_completion_rate_pct  fertility_rate_births_per_woman
# 1194                    33.973301                            6.110
# 815                     62.643440                            4.519
# 1058                    98.644608                            3.114
# 670                     71.137070                            4.157
# 16                      54.809158                            5.013

# %%
# save train and test dataset
train_data[features_columns + [target_column]].to_csv("malaria_control_africa_train_data.csv", index=False)
test_data[features_columns + [target_column]].to_csv("malaria_control_africa_test_data.csv", index=False)

# %%
# standardizing data
from sklearn.preprocessing import StandardScaler

st_scaler = StandardScaler()
X_train_scaled = st_scaler.fit_transform(X_train)
X_test_scaled = st_scaler.transform(X_test)
X_train_scaled, X_test_scaled
# Out:
# (array([[-3.76447659e-02, -1.45628684e+00,  4.80454677e-01, ...,
#          -5.23227083e-01, -4.09381335e-01,  6.21557912e-01],
#         [ 9.03788540e-01, -2.75195697e+00,  2.35069667e+00, ...,
#           4.26321134e-03,  1.01107686e-01, -6.95610023e-01],
#         [ 9.16252234e-01, -1.13136942e+00,  7.25111096e-01, ...,
#           4.83733619e-01,  1.42016172e+00, -1.92870341e+00],
#         ...,
#         [-5.28268669e-01,  2.39394997e-01, -5.74162543e-01, ...,
#          -2.20948183e-01,  2.31535535e-01,  7.69100503e-01],
#         [-2.02968658e-01, -5.80804490e-01, -1.74259576e-03, ...,
#          -8.92320771e-01,  2.04914483e-01,  1.01225729e+00],
#         [-6.66492431e-01,  2.93645966e-01, -6.59344293e-01, ...,
#          -7.81927961e-02, -2.48754693e-01,  9.52910547e-01]]),
#  array([[-0.53068832,  1.04608866, -0.58946616, ..., -0.11585281,
#          -1.5068082 ,  1.10869574],
#         [-0.28591597, -0.09790952, -0.5152105 , ..., -0.96920912,
#          -0.14052366, -0.20270237],
#         [ 1.54793272, -1.09281647,  1.56055089, ...,  1.1081121 ,
#           1.57512334, -1.36078807],
#         ...,
#         [ 0.15786091, -0.67612115,  0.21173763, ...,  0.26783915,
#           1.22719963, -0.53652779],
#         [ 0.01518822,  0.51587466, -0.13376031, ..., -0.24127047,
#           0.48377414, -0.57197098],
#         [-0.25987258, -0.11953997, -0.32353052, ...,  0.02571467,
#           0.97488858, -1.24539163]]))

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=features_columns, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=features_columns, index=X_test.index)
X_train_scaled.describe()
# Out:
#        health_expenditure_per_capita_usd  rural_population_pct  \
# count                       9.400000e+02          9.400000e+02
# mean                        1.152742e-16          1.360614e-16
# std                         1.000532e+00          1.000532e+00
# min                        -7.544460e-01         -2.972329e+00
# 25%                        -5.578769e-01         -7.296660e-01
# 50%                        -3.667872e-01          9.388480e-02
# 75%                        -8.812324e-03          7.552931e-01
# max                         5.085056e+00          1.917003e+00
#
#        gdp_per_capita_usd  forest_area_pct  population_density  \
# count        9.400000e+02     9.400000e+02        9.400000e+02
# mean        -2.267690e-17    -5.999929e-17       -1.417306e-17
# std          1.000532e+00     1.000532e+00        1.000532e+00
# min         -7.717919e-01    -1.258897e+00       -8.075396e-01
# 25%         -5.721618e-01    -8.158440e-01       -6.425866e-01
# 50%         -3.756463e-01    -2.341389e-01       -3.185968e-01
# 75%          1.222471e-01     6.198229e-01        1.730679e-01
# max          7.375203e+00     2.546007e+00        5.393253e+00
#
#        under5_mortality_per_1000  life_expectancy_years  \
# count               9.400000e+02           9.400000e+02
# mean               -1.587383e-16          -3.023586e-17
# std                 1.000532e+00           1.000532e+00
# min                -1.635968e+00          -5.870371e+00
# 25%                -7.497567e-01          -6.346932e-01
# 50%                -1.777021e-01           4.227820e-02
# 75%                 5.976631e-01           6.164421e-01
# max                 7.565924e+00           2.408358e+00
#
#        basic_water_access_pct  govt_health_exp_pct_gdp  \
# count            9.400000e+02             9.400000e+02
# mean             5.102302e-17            -1.795254e-17
# std              1.000532e+00             1.000532e+00
# min             -2.640968e+00            -1.309863e+00
# 25%             -7.148742e-01            -6.957330e-01
# 50%             -5.204781e-02            -2.741578e-01
# 75%              7.454451e-01             3.380867e-01
# max              2.202127e+00             4.461270e+00
#
#        primary_completion_rate_pct  fertility_rate_births_per_woman
# count                 9.400000e+02                     9.400000e+02
# mean                  4.516482e-16                    -5.763711e-16
# std                   1.000532e+00                     1.000532e+00
# min                  -2.377962e+00                    -2.757085e+00
# 25%                  -6.119032e-01                    -6.461544e-01
# 50%                  -6.325302e-02                     6.312157e-02
# 75%                   7.819104e-01                     6.844078e-01
# max                   2.340126e+00                     2.525599e+00

# %%
X_test_scaled.describe()
# Out:
#        health_expenditure_per_capita_usd  rural_population_pct  \
# count                         236.000000            236.000000
# mean                            0.056961             -0.022401
# std                             1.115784              0.985606
# min                            -0.763313             -2.831795
# 25%                            -0.555789             -0.810752
# 50%                            -0.350932              0.025633
# 75%                             0.016280              0.686718
# max                             5.452655              1.880118
#
#        gdp_per_capita_usd  forest_area_pct  population_density  \
# count          236.000000       236.000000          236.000000
# mean             0.025950        -0.095848            0.031656
# std              0.906698         0.963466            1.045825
# min             -0.770976        -1.258897           -0.806689
# 25%             -0.538665        -0.815893           -0.621188
# 50%             -0.351307        -0.318647           -0.343980
# 75%              0.174670         0.481400            0.158796
# max              3.778365         2.521681            4.600646
#
#        under5_mortality_per_1000  life_expectancy_years  \
# count                 236.000000             236.000000
# mean                   -0.039742               0.038841
# std                     1.063875               0.968640
# min                    -1.647108              -6.466684
# 25%                    -0.772037              -0.562469
# 50%                    -0.236746               0.072216
# 75%                     0.616045               0.679763
# max                     9.007479               2.377630
#
#        basic_water_access_pct  govt_health_exp_pct_gdp  \
# count              236.000000               236.000000
# mean                 0.092616                 0.011667
# std                  1.000861                 1.083537
# min                 -2.194452                -1.349675
# 25%                 -0.664745                -0.736439
# 50%                  0.062770                -0.270414
# 75%                  0.866780                 0.275633
# max                  2.142297                 4.465524
#
#        primary_completion_rate_pct  fertility_rate_births_per_woman
# count                   236.000000                       236.000000
# mean                      0.001453                        -0.029222
# std                       0.945146                         1.017498
# min                      -1.926010                        -2.682077
# 25%                      -0.585208                        -0.713538
# 50%                       0.024958                         0.051994
# 75%                       0.709483                         0.743548
# max                       1.905579                         2.209083

# %%
import joblib
joblib.dump(st_scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %% [markdown]
# # Linear Regression OLS

# %%
linear_model = LinearRegression()
linear_model
# Out:
# LinearRegression()

# %%
linear_model.fit(X_train_scaled, Y_train)
# Out:
# LinearRegression()

# %%
Y_train_pred = linear_model.predict(X_train_scaled)
Y_test_pred = linear_model.predict(X_test_scaled)

# %%
ols_train_rmse = root_mean_squared_error(Y_train, Y_train_pred)
ols_test_rmse = root_mean_squared_error(Y_test, Y_test_pred)
ols_train_mae = mean_absolute_error(Y_train, Y_train_pred)
ols_test_mae = mean_absolute_error(Y_test, Y_test_pred)
ols_r2_train_score = r2_score(Y_train, Y_train_pred) * 100
ols_r2_test_score = r2_score(Y_test, Y_test_pred) * 100

# %%
print("Train MAE:", round(ols_train_mae, 2))
print("Test MAE:", round(ols_test_mae, 2))
print("Train RMSE:", round(ols_train_rmse,2))
print("Test RMSE:", round(ols_test_rmse, 2))
print("Train R² in %:", round(ols_r2_train_score, 3))
print("Test R² in %:", round(ols_r2_test_score, 2))
# Out:
# Train MAE: 82.57
# Test MAE: 85.08
# Train RMSE: 101.38
# Test RMSE: 109.98
# Train R² in %: 58.061
# Test R² in %: 57.96

# %%
row = X_test_scaled.iloc[[0]]
actual = Y_test.iloc[0]
predicted = linear_model.predict(row)[0]

# %%
print("Actual malaria incidence:   ", round(actual, 3))
print("Predicted malaria incidence:", round(predicted, 3))
print("Difference:                 ", round(predicted - actual, 3))
# Out:
# Actual malaria incidence:    519.268
# Predicted malaria incidence: 330.227
# Difference:                  -189.041

# %% [markdown]
# ### The negative prediction in the predicted malaria incidence while the actual malaria incidence is 0 is due to the fact that some countries have managed to eradicate malaria cases. However, the straight line of linear regression goes beyond 0, else giving a negative value

# %% [markdown]
# # SGD Implementation

# %%
# SGD Regression
warnings.filterwarnings("ignore", category=UserWarning)
nbr_turn = 50500
learning_rate_eta=0.0001
sgd_model = SGDRegressor(
    loss="squared_error",
    learning_rate="invscaling",
    eta0=learning_rate_eta,
    random_state=42
)

# %%
train_losses = []
test_losses = []
for epoch in range(nbr_turn):
    sgd_model.partial_fit(X_train_scaled, Y_train)
    train_pred = sgd_model.predict(X_train_scaled)
    test_pred = sgd_model.predict(X_test_scaled)
    train_losses.append(root_mean_squared_error(Y_train, train_pred))
    test_losses.append(root_mean_squared_error(Y_test, test_pred))

# %%
sgd_train_rmse = train_losses[np.argmin(train_losses)]
sgd_test_rmse = test_losses[np.argmin(test_losses) ]
sgd_mae_train = mean_absolute_error(Y_train, sgd_model.predict(X_train_scaled))
sgd_mae_test = mean_absolute_error(Y_test, sgd_model.predict(X_test_scaled))
sgd_r2_train = r2_score(Y_train, sgd_model.predict(X_train_scaled)) * 100
sgd_r2_test = r2_score(Y_test, sgd_model.predict(X_test_scaled)) * 100

# %%
best_epoch = np.argmin(test_losses)
best_epoch_value = test_losses[best_epoch]

# %%
print(f"Train lossess:", train_losses)
print(f"Test Losses:", test_losses)
print("SGD Train MAE:", round(sgd_mae_train, 2))
print("SGD Test MAE:", round(sgd_mae_test, 2))
print("SGD Train RMSE:", round(sgd_train_rmse, 2))
print("SGD Test RMSE:", round(sgd_test_rmse, 2))
print("SGD Train R2:", round(sgd_r2_train, 2))
print("SGD Test R2:", round(sgd_r2_test, 2))

print("_____________________________________________________________")

print(f"Test loss is lowest at epoch {best_epoch + 1}, value = {best_epoch_value:.2f}")
# Out:
# Train lossess: [252.7989061326253, 247.48768520465507, 243.12588183852932, 239.34158626975915, 235.9660725853569, 232.90263082180746, 230.08861874467408, 227.4802490069742, 225.04527577660684, 222.75903478027126, 220.60210937599973, 218.5588644123097, 216.6164782112624, 214.7642773782296, 212.99326447011, 211.29577330075972, 209.66521149455878, 208.09586434665488, 206.58274279838488, 205.1214638217726, 203.70815505065252, 202.33937784639375, 201.01206458200807, 199.72346703469157, 198.47111355820525, 197.25277326775606, 196.06642587940917, 194.9102361488287, 193.782532080945, 192.68178625402965, 191.6065997333464, 190.55568815142522, 189.52786961157673, 188.52205413392036, 187.53723441295776, 186.57247769550162, 185.6269186198243, 184.69975288286352, 183.79023162350956, 182.89765642737876, 182.02137487280928, 181.1607765496966, 180.31528949268355, 179.48437697849548, 178.66753464417204, 177.86428788881955, 177.07418952647157, 176.29681766188492, 175.53177376469313, 174.7786809204348, 174.03718223961897, 173.3069394082763, 172.58763136541657, 171.87895309451756, 171.1806145176595, 170.49233948220623, 169.81386483106277, 169.144939548529, 168.48532397462526, 167.8347890815375, 167.19311580648602, 166.56009443592365, 165.9355240364814, 165.31921192854904, 164.7109731987841, 164.1106302482083, 163.5180123728742, 162.93295537437567, 162.35530119773279, 161.78489759441194, 161.22159780845158, 160.66526028384703, 160.11574839151606, 159.57293017431522, 159.03667810871474, 158.5068688818577, 157.98338318284445, 157.46610550717432, 156.95492397337728, 156.44973015093956, 155.95041889870802, 155.45688821302184, 154.96903908488093, 154.48677536551867, 154.0100036397928, 153.53863310685878, 153.0725754676284, 152.6117448185572, 152.15605755133592, 151.70543225810013, 151.2597896417909, 150.81905243133826, 150.38314530135332, 149.95199479604562, 149.52552925709654, 149.10367875524517, 148.68637502535358, 148.2735514047423, 147.86514277459452, 147.46108550424583, 147.0613173981881, 146.66577764562604, 146.2744067724396, 145.8871465954101, 145.50394017858218, 145.12473179163942, 144.74946687018036, 144.3780919777885, 144.0105547697975, 143.6468039586578, 143.2867892808191, 142.93046146504562, 142.57777220208897, 142.2286741156447, 141.88312073452855, 141.54106646600562, 141.2024665702155, 140.86727713563644, 140.53545505553575, 140.2069580053575, 139.88174442100132, 139.55977347794715, 139.24100507118573, 138.92539979591515, 138.61291892896745, 138.3035244109294, 137.99717882892642, 137.6938454000366, 137.39348795530668, 137.09607092434365, 136.80155932045236, 136.50991872629845, 136.22111528006945, 135.9351156621149, 135.65188708204212, 135.37139726625009, 135.0936144458794, 134.81850734516374, 134.546045170163, 134.27619759786427, 134.00893476563323, 133.74422726100286, 133.48204611178556, 133.22236277649387, 132.96514913505973, 132.71037747983786, 132.45802050688445, 132.20805130749775, 131.96044336001196, 131.7151705218354, 131.47220702171913, 131.23152745225434, 130.993106762583, 130.7569202513173, 130.5229435596614, 130.29115266472294, 130.06152387301185, 129.83403381411958, 129.60865943456884, 129.38537799183067, 129.16416704850275, 128.94500446664094, 128.72786840224103, 128.51273729986582, 128.29958988741015, 128.0884051710001, 127.87916243002378, 127.67184121228648, 127.46642132928707, 127.26288285161263, 127.0612061044463, 126.86137166318478, 126.66336034916078, 126.46715322547139, 126.27273159290293, 126.0800769859533, 125.88917116894882, 125.6999961322493, 125.51253408854231, 125.32676746922209, 125.14267892085066, 124.96025130169842, 124.7794676783623, 124.60031132246014, 124.42276570739624, 124.24681450519891, 124.0724415834261, 123.89963100213812, 123.7283670109342, 123.55863404605361, 123.39041672753577, 123.22369985644198, 123.05846841213337, 122.89470754960517, 122.73240259687549, 122.57153905242822, 122.41210258270624, 122.25407901965548, 122.09745435831783, 121.94221475447088, 121.78834652231548, 121.63583613220693, 121. ...
# Test Losses: [259.53449339280854, 254.32034396745945, 250.0409930356533, 246.33036580288757, 243.02225663411696, 240.0213662383649, 237.265956860436, 234.71287251548267, 232.33033450306084, 230.09403906038403, 227.9848567510118, 225.98738693272648, 224.08900318218082, 222.2791972559714, 220.5491132145973, 218.8912074204487, 217.2989945906346, 215.7668543248796, 214.28988115410223, 212.86376656346695, 211.48470493798743, 210.14931769676807, 208.85459145596698, 207.5978271518374, 206.37659782605238, 205.18871332927623, 204.032190602884, 202.90522849749792, 201.80618631083166, 200.73356539696528, 199.68599332914326, 198.66221019873947, 197.66105671156865, 196.68146380456594, 195.72244355496704, 194.78308119338286, 193.86252806379923, 192.95999539916474, 192.07474880214068, 191.20610333773743, 190.3534191587044, 189.51609759626302, 188.69357765853843, 187.8853328872102, 187.09086852976742, 186.30971899054776, 185.54144552863443, 184.7856341748663, 184.0418938437604, 183.3098546191989, 182.58916619533798, 181.8794964564523, 181.1805301813688, 180.49196785982616, 179.8135246095611, 179.14492918419177, 178.4859230630791, 177.83625961532246, 177.19570333088907, 176.56402911263459, 175.94102162362157, 175.32647468473172, 174.72019071807316, 174.1219802321454, 173.53166134512492, 172.94905934299166, 172.37400626953746, 171.80634054558143, 171.24590661497123, 170.69255461517432, 170.14614007046956, 169.60652360593022, 169.0735706805528, 168.54715133803342, 168.02713997382807, 167.51341511724902, 167.00585922746154, 166.50435850233728, 166.0088026992159, 165.51908496669898, 165.03510168667893, 164.55675232586685, 164.0839392961452, 163.61656782312562, 163.15454582234025, 162.69778378254142, 162.24619465562495, 161.7996937527305, 161.35819864610403, 160.92162907634565, 160.48990686468392, 160.06295582995628, 159.64070170998917, 159.2230720871004, 158.80999631746187, 158.40140546408435, 157.99723223319674, 157.5974109138166, 157.20187732031442, 156.81056873779303, 156.4234238701158, 156.04038279042513, 155.6613868940088, 155.28637885337508, 154.91530257541228, 154.5481031605135, 154.18472686355608, 153.8251210566321, 153.4692341934338, 153.11701577520242, 152.76841631815662, 152.42338732232048, 152.08188124167714, 151.74385145557602, 151.40925224133161, 151.07803874794894, 150.75016697091917, 150.42559372803137, 150.10427663614817, 149.7861740888969, 149.4712452352334, 149.15944995883208, 148.8507488582644, 148.54510322792729, 148.24247503968522, 147.94282692519263, 147.64612215886459, 147.3523246414656, 147.06139888428706, 146.77330999388923, 146.48802365737828, 146.20550612819792, 145.92572421241007, 145.64864525544488, 145.37423712929802, 145.102468220158, 144.8333074164416, 144.56672409722418, 144.30268812104424, 144.04116981506982, 143.7821399646096, 143.52556980295466, 143.27143100153978, 143.0196956604071, 142.77033629896442, 142.52332584702296, 142.27863763610637, 142.03624539101776, 141.7961232216564, 141.55824561507552, 141.32258742776705, 141.08912387817253, 140.85783053940423, 140.62868333217273, 140.40165851791437, 140.1767326921059, 139.95388277776485, 139.73308601912808, 139.5143199754992, 139.29756251526138, 139.08279181005045, 138.86998632907896, 138.65912483361015, 138.45018637157523, 138.24315027232788, 138.0379961415321, 137.83470385618023, 137.63325355973495, 137.43362565739167, 137.23580081145832, 137.03975993684804, 136.84548419668087, 136.6529549979897, 136.46215398753222, 136.2730630476984, 136.08566429251587, 135.89994006374891, 135.71587292708588, 135.53344566841542, 135.35264129018762, 135.1734430078567, 134.99583424640358, 134.819798636936, 134.64532001336488, 134.47238240915146, 134.3009700541274, 134.13106737138207, 133.9626589742183, 133.7957296631708, 133.63026442309035, 133.46624842028675, 133.30366699973374, 133.14250568233018, 132.98275016221837, 132.82438630415635, 132.6674001409454, 132.5117778709076, 132.35750585541496, 132.20457061646744, 132.05295883431825, 131.9026573451474, 131.75365313877916, 131. ...
# SGD Train MAE: 82.57
# SGD Test MAE: 85.08
# SGD Train RMSE: 101.38
# SGD Test RMSE: 109.98
# SGD Train R2: 58.06
# SGD Test R2: 57.96
# _____________________________________________________________
# Test loss is lowest at epoch 15631, value = 109.98

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, nbr_turn + 1), train_losses, label="Train Loss (RMSE)")
plt.plot(range(1, nbr_turn + 1), test_losses, label="Test Loss (RMSE)")
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.title("SGD Regressor — Train vs Test Loss Curve")
plt.legend()
plt.show()

# %% [markdown]
# # DecisionTree Model

# %%
dt_model = DecisionTreeRegressor(
    random_state=42,
    max_depth=15
    )
dt_model.fit(X_train_scaled, Y_train)

Y_train_pred_dt = dt_model.predict(X_train_scaled)
Y_test_pred_dt = dt_model.predict(X_test_scaled)

# %%
best_depth = 0
best_test_r2 = float("-inf")

for depth in range(1, 21):
    dt = DecisionTreeRegressor(max_depth=depth, random_state=42)
    dt.fit(X_train_scaled, Y_train)
    train_r2 = r2_score(Y_train, dt.predict(X_train_scaled))
    test_r2 = r2_score(Y_test, dt.predict(X_test_scaled))
    print(f"max_depth={depth}: Train R²={train_r2*100:.2f}%, Test R²={test_r2*100:.2f}%")
    if test_r2 > best_test_r2:
        best_test_r2 = test_r2
        best_depth = depth

print(f"\nBest depth found: {best_depth}, Test R²={best_test_r2*100:.2f}%")
# Out:
# max_depth=1: Train R²=40.33%, Test R²=45.66%
# max_depth=2: Train R²=55.88%, Test R²=58.04%
# max_depth=3: Train R²=63.81%, Test R²=62.56%
# max_depth=4: Train R²=70.58%, Test R²=65.87%
# max_depth=5: Train R²=77.15%, Test R²=71.88%
# max_depth=6: Train R²=85.65%, Test R²=82.09%
# max_depth=7: Train R²=90.42%, Test R²=83.82%
# max_depth=8: Train R²=94.07%, Test R²=86.48%
# max_depth=9: Train R²=96.08%, Test R²=88.04%
# max_depth=10: Train R²=97.83%, Test R²=85.39%
# max_depth=11: Train R²=98.93%, Test R²=89.03%
# max_depth=12: Train R²=99.43%, Test R²=89.70%
# max_depth=13: Train R²=99.64%, Test R²=88.30%
# max_depth=14: Train R²=99.77%, Test R²=91.80%
# max_depth=15: Train R²=99.87%, Test R²=89.04%
# max_depth=16: Train R²=99.93%, Test R²=90.49%
# max_depth=17: Train R²=99.96%, Test R²=88.18%
# max_depth=18: Train R²=99.98%, Test R²=90.93%
# max_depth=19: Train R²=99.99%, Test R²=91.17%
# max_depth=20: Train R²=100.00%, Test R²=89.07%
#
# Best depth found: 14, Test R²=91.80%

# %% [markdown]
# ### For DecisionTree Regressor, since hyperparameters exists, we choose the highest R2 score which is leave 8 and R2 = 30.70

# %%
dt_train_rmse = root_mean_squared_error(Y_train, Y_train_pred_dt)
dt_test_rmse = root_mean_squared_error(Y_test, Y_test_pred_dt)
dt_train_mae = mean_absolute_error(Y_train, Y_train_pred_dt)
dt_test_mae = mean_absolute_error(Y_test, Y_test_pred_dt)
dt_r2_score_train = r2_score(Y_train, Y_train_pred_dt) * 100
dt_r2_score_test = r2_score(Y_test, Y_test_pred_dt) * 100

# %%
print("Train RMSE:", round(dt_train_rmse, 2))
print("Test RMSE:", round(dt_test_rmse, 2))
print("Train MAE:", round(dt_train_mae, 2))
print("Test MAE:", round(dt_test_mae, 2))
print("Train R² in %:", round(dt_r2_score_train, 2))
print("Test R² in %:", round(dt_r2_score_test, 2))
# Out:
# Train RMSE: 5.63
# Test RMSE: 56.16
# Train MAE: 1.62
# Test MAE: 25.46
# Train R² in %: 99.87
# Test R² in %: 89.04

# %% [markdown]
# ### Random Forest

# %%
rf_model = RandomForestRegressor(
    n_estimators=200,
    random_state=42
    )

# %%
rf_model.fit(X_train_scaled, Y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
Y_train_pred_rf = rf_model.predict(X_train_scaled)
Y_test_pred_rf = rf_model.predict(X_test_scaled)

# %%
rf_train_rmse = root_mean_squared_error(Y_train, Y_train_pred_rf)
rf_test_rmse = root_mean_squared_error(Y_test, Y_test_pred_rf)
rf_train_r2_score = r2_score(Y_train, Y_train_pred_rf) * 100
rf_test_r2_score = r2_score(Y_test, Y_test_pred_rf) * 100
rf_train_mae = mean_absolute_error(Y_train, Y_train_pred_rf)
rf_test_mae = mean_absolute_error(Y_test, Y_test_pred_rf)

# %%
print("Train MAE:", round(rf_train_mae, 2))
print("Test MAE:", round(rf_test_mae, 2))
print("Train RMSE:", round(rf_train_rmse, 2))
print("Test RMSE:", round(rf_test_rmse, 2))
print("Train R² in %:", round(rf_train_r2_score, 2))
print("Test R² in %:", round(rf_test_r2_score, 2))
# Out:
# Train MAE: 9.12
# Test MAE: 24.14
# Train RMSE: 14.36
# Test RMSE: 41.16
# Train R² in %: 99.16
# Test R² in %: 94.11

# %%
feature = "fertility_rate_births_per_woman"
X_single = train_data[[feature]]
y_single = train_data[target_column]

rf_single_model = RandomForestRegressor(n_estimators=200, random_state=42)
rf_single_model.fit(X_single, y_single)

x_range = np.linspace(X_single[feature].min(), X_single[feature].max(), 300).reshape(-1, 1)
x_range_df = pd.DataFrame(x_range, columns=[feature])
y_range_pred = rf_single_model.predict(x_range_df)

plt.figure(figsize=(8, 6))
plt.scatter(X_single, y_single, alpha=0.5, label="Actual data")
plt.plot(x_range_df, y_range_pred, color="green", linewidth=2, label="Random Forest fit")
plt.xlabel("Fertility rate (births per woman)")
plt.ylabel("Malaria incidence per 1,000 at risk")
plt.title("Malaria Incidence vs. Fertility Rate — Random Forest Fit")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

feature = "fertility_rate_births_per_woman"
X_single = train_data[[feature]]
y_single = train_data[target_column]

simple_model = LinearRegression()
simple_model.fit(X_single, y_single)

plt.figure(figsize=(8, 6))
plt.scatter(X_single, y_single, alpha=0.5, label="Actual data")
x_range = pd.DataFrame({feature: [X_single[feature].min(), X_single[feature].max()]})
plt.plot(x_range, simple_model.predict(x_range), color="red", linewidth=2, label="Fitted line")
plt.xlabel("Fertility rate (births per woman)")
plt.ylabel("Malaria incidence per 1,000 at risk")
plt.title("Malaria Incidence vs. Fertility Rate — Fitted Line")
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# OLS panel
axes[0].scatter(X_single, y_single, alpha=0.5, label="Actual data")
x_range_ols = pd.DataFrame({feature: [X_single[feature].min(), X_single[feature].max()]})
axes[0].plot(x_range_ols, simple_model.predict(x_range_ols), color="red", linewidth=2, label="OLS fit")
axes[0].set_xlabel("Fertility rate (births per woman)")
axes[0].set_ylabel("Malaria incidence per 1,000 at risk")
axes[0].set_title("OLS (Linear Regression)")
axes[0].legend()

# Random Forest panel
axes[1].scatter(X_single, y_single, alpha=0.5, label="Actual data")
axes[1].plot(x_range_df, y_range_pred, color="green", linewidth=2, label="Random Forest fit")
axes[1].set_xlabel("Fertility rate (births per woman)")
axes[1].set_title("Random Forest")
axes[1].legend()

fig.suptitle("Malaria Incidence vs. Fertility Rate — OLS vs Random Forest", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# comparing all methods
comparison_metrics = {
    "OLS": [ols_train_rmse, ols_test_rmse, ols_train_mae, ols_test_mae, ols_r2_train_score, ols_r2_test_score],
    "SGD Regressor": [sgd_train_rmse, sgd_test_rmse, sgd_mae_train, sgd_mae_test, sgd_r2_train, sgd_r2_test],
    "Decision Tree": [dt_train_rmse, dt_test_rmse, dt_train_mae, dt_test_mae, dt_r2_score_train, dt_r2_score_test],
    "Random Forest": [rf_train_rmse, rf_test_rmse, rf_train_mae, rf_test_mae, rf_train_r2_score, rf_test_r2_score],
}

# %%
results = pd.DataFrame(comparison_metrics, index=["Train RMSE", "Test RMSE", "Train MAE", "Test MAE", "Train R² (%)", "Test R² (%)"])
results.round(2)
# Out:
#                  OLS  SGD Regressor  Decision Tree  Random Forest
# Train RMSE    101.38         101.38           5.63          14.36
# Test RMSE     109.98         109.98          56.16          41.16
# Train MAE      82.57          82.57           1.62           9.12
# Test MAE       85.08          85.08          25.46          24.14
# Train R² (%)   58.06          58.06          99.87          99.16
# Test R² (%)    57.96          57.96          89.04          94.11

# %%
X_train_scaled.head()
# Out:
#      health_expenditure_per_capita_usd  rural_population_pct  \
# 155                          -0.037645             -1.456287
# 418                           0.903789             -2.751957
# 36                            0.916252             -1.131369
# 715                          -0.680432              0.237201
# 339                          -0.578705              1.745478
#
#      gdp_per_capita_usd  forest_area_pct  population_density  \
# 155            0.480455         0.956730           -0.582876
# 418            2.350697         2.476775           -0.751490
# 36             0.725111        -0.740932           -0.077156
# 715           -0.678466         1.858980           -0.398339
# 339           -0.723572        -0.952429            2.753692
#
#      under5_mortality_per_1000  life_expectancy_years  basic_water_access_pct  \
# 155                  -0.635569               0.419263                0.022833
# 418                  -0.905164               0.952541                1.392261
# 36                   -1.348548               1.840763                1.062139
# 715                   2.000228              -1.311952               -0.465872
# 339                   0.115288              -0.375341               -0.353297
#
#      govt_health_exp_pct_gdp  primary_completion_rate_pct  \
# 155                -0.523227                    -0.409381
# 418                 0.004263                     0.101108
# 36                  0.483734                     1.420162
# 715                -0.871270                    -1.782618
# 339                 0.382356                    -0.622520
#
#      fertility_rate_births_per_woman
# 155                         0.621558
# 418                        -0.695610
# 36                         -1.928703
# 715                         0.841635
# 339                         1.232335

# %% [markdown]
# ### Based on different RMSE, MAE, and R2 on both training and testing, the best performing model is Random Forest. Random Forest outperfom both OLS and SGD because Random Forest can also pick Non-linear relationship that linear regression can not. Linear regression just finds a line of best fit. Random Forest outperforms Decision Tree Regressor because it averages result of leaf values, which also reduces biases and noises

# %%
# save model
joblib.dump(rf_model, "model.pkl")
joblib.dump(st_scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
for predict_case_index in range(5):
    row = X_test_scaled.iloc[[predict_case_index]]
    actual = Y_test.iloc[predict_case_index]
    predicted = rf_model.predict(row)[0]
    print("Actual malaria incidence per 1000 cases   :", round(actual, 3))
    print("predicted malaria incidence per 1000 cases:", round(predicted, 3))
    print("\n")
# Out:
# Actual malaria incidence per 1000 cases   : 519.268
# predicted malaria incidence per 1000 cases: 523.607
#
#
# Actual malaria incidence per 1000 cases   : 74.164
# predicted malaria incidence per 1000 cases: 139.755
#
#
# Actual malaria incidence per 1000 cases   : 3.865
# predicted malaria incidence per 1000 cases: 1.844
#
#
# Actual malaria incidence per 1000 cases   : 219.463
# predicted malaria incidence per 1000 cases: 219.057
#
#
# Actual malaria incidence per 1000 cases   : 277.322
# predicted malaria incidence per 1000 cases: 282.905
